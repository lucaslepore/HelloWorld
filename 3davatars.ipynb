# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaslepore/HelloWorld/blob/master/3davatars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm videoavatars

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd ..

# %%
cd content

# %%
# !rm -rf videoavatars

# %%
# %cd videoavatars

# %%
# !pip install opendr

# %%
# !git clone https://github.com/mattloper/opendr.git
# !pip install -r requirements.txt

# %%
cd

# %%
# %cd opendr
# !pip install -r requirements.txt

# %%
# %cd ..

# %%
# %cd ..
# !mv videoavatars.zip /content

# %%
# !unzip videoavatars

# %%
# !ls
# !unzip videoavatars.zip

# %%
# !ls
# !unzip videoavatars

# %%
# %cd videoavatars
# !pip install -r requirements.txt

# %%
# %cd ..
# !git clone https://github.com/mattloper/opendr.git

# %%
# %cd opendr
# !pip install -r requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# !ls
# !./run_step1.sh people_snapshot_public content
# Out:
# assets			README.md	  run_step3.sh	      util
# lib			render		  step1_pose.py       vendor
# models			requirements.txt  step2_consensus.py
# people_snapshot_public	run_step1.sh	  step3_texture.py
# prepare_data		run_step2.sh	  tex
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# c
# Traceback (most recent call last):
#   File "step1_pose.py", line 412, in <module>
#     args.body_height, args.nohands, args.display)
#   File "step1_pose.py", line 257, in main
#     with open(model_file, 'rb') as fp:
# IOError: [Errno 2] No such file or directory: 'vendor/smpl/models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl'

# %%
# !mv basicmodel_m_lbs_10_207_0_v1.0.0.pkl videoavatars/vendor/smpl/models

# %%
# %cd videoavatars
# Out:
# /content/videoavatars

# %%
# !./run_step1.sh people_snapshot_public/female-1-casual people_snapshot_public/female-1-casual
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2
# ['v2lens', 'betas2lens', 'v2rads', 'betas2rads']
# [[ 5.98342341e-03  9.25230851e-03  9.25198959e-03 ...  1.14589768e-02
#    0.00000000e+00  1.57772181e-29]
#  [-9.30352985e-04  5.82105285e-03  5.82068789e-03 ...  3.21515512e-03
#    0.00000000e+00 -4.04291214e-30]
#  [ 1.66023426e-04 -1.87512838e-03 -1.87476292e-03 ... -3.49334638e-03
#    0.00000000e+00  2.95822839e-30]
#  ...
#  [ 1.64621909e-04  2.88700164e-05  2.87887356e-05 ... -5.51262932e-05
#    0.00000000e+00  1.57772181e-30]
#  [ 7.00526497e-05  3.78082333e-05  3.78725148e-05 ... -2.17036997e-05
#    0.00000000e+00  1.77493704e-30]
#  [ 1.13171800e-01  1.98943654e-01  1.98943305e-01 ...  2.45309008e-01
# ...
